# %% [markdown]
# <div style="text-align: center; font-family: Georgia, 'Times New Roman', serif; color: #111; line-height: 1.5; margin-top: 20px;">
#
# <img src="https://oci02.img.iteso.mx/Identidades-De-Instancia/ITESO/Logos%20ITESO/Logo-ITESO-Vertical-SinFondo.png" width="300" style="margin-bottom: 30px;"/>
#
# <div style="font-size: 18px; font-style: italic; margin-bottom: 8px;"> ITESO, Universidad Jesuita de Guadalajara </div>
# <div style="font-size: 22px; font-weight: bold; letter-spacing: 0.5px; margin-bottom: 22px;"> PROYECTO PAP · PRIMAVERA 2026 </div>
# <div style="font-size: 18px; margin-bottom: 10px;"> <span style="font-style: italic;">Programa PAP:</span> Modelación Matemática para el Desarrollo de Planes de Negocio </div>
# <div style="font-size: 18px; margin-bottom: 10px;"> Optimización de Programas de Inversión en Intermediarios Financieros </div>
# <div style="font-size: 30px; font-weight: bold; margin: 40px auto 45px auto; max-width: 900px; line-height: 1.35;"> Modelo económico-operativo con incertidumbre para transporte público </div>
# <div style="font-size: 18px; font-weight: bold; margin-bottom: 18px;"> Presentan </div>
# <div style="font-size: 17px; margin-bottom: 40px; line-height: 1.9;"> ANA PAULA MORENO HARO<br> ÚRSULA SARAHÍ VARGAS LÓPEZ<br> ARANTZA GÓMEZ HARO GAMBOA<br> JAVIER ALEJANDRO FAJARDO LÓPEZ </div>
# <div style="font-size: 18px; font-weight: bold; margin-bottom: 12px;"> Profesor </div>
# <div style="font-size: 17px;"> LUIS CARLOS ALVARADO GARNICA </div>
# </div>
